# %%
import pandas as pd
pd.options.display.max_rows = 60 #None #60
pd.options.display.max_columns = 60 # None #70
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Participante MD
#
# ## MD CONTROL

# %%
# read csv
df_datos1 = pd.read_csv('MD_control.csv')
df_datos1
# Out:
#               Hora  B: BVP  E: Skin Cond  G: Abd Resp
# 0         0.000488   0.000        10.389       35.289
# 1         0.000977   0.000        10.389       35.289
# 2         0.001465   0.000        10.389       35.289
# 3         0.001953   0.000        10.389       35.289
# 4         0.002441   0.001        10.389       35.289
# ...            ...     ...           ...          ...
# 535675  261.560547  35.898         9.430       34.796
# 535676  261.561035  35.898         9.430       34.796
# 535677  261.561523  35.898         9.430       34.796
# 535678  261.562012  35.897         9.430       34.796
# 535679  261.562500  35.897         9.430       34.796
#
# [535680 rows x 4 columns]

# %%
#GRAFICA DE PULSO
fig,A = plt.subplots(1,1,figsize=(15,5))
A.plot(df_datos1['B: BVP'])
A.set_ylabel('BVP',fontsize=20)
A.set_xlabel('time',fontsize=15)
A.set_xlim(50,500000)                               ## DATO TUNEADO
A.set_ylim(30,45)                                ## DATO TUNEADO
A.set_title('MD control',fontsize=20)

# GRAFO CONDUCTANCIA
fig,B = plt.subplots(1,1,figsize=(15,5))
B.plot(df_datos1['E: Skin Cond'])
B.set_ylabel('Skin Conductance',fontsize=20)
B.set_xlabel('time',fontsize=15)
B.set_title('MD control',fontsize=20)

#GRAFO RESPIRACION
fig,C = plt.subplots(1,1,figsize=(15,5))
C.plot(df_datos1['G: Abd Resp'])
C.set_ylabel('Breathing',fontsize=20)
C.set_xlabel('time',fontsize=15)
C.set_title('MD control',fontsize=20)

plt.show()

# %% [markdown]
# ## MD AMBIGÜEDAD

# %%
# read csv
df_datos2 = pd.read_csv('MD_ambiguedad.csv')
df_datos2
# Out:
#               Hora  B: BVP  E: Skin Cond  G: Abd Resp
# 0         0.000488   0.000         9.271       35.689
# 1         0.000977   0.000         9.271       35.689
# 2         0.001465   0.000         9.271       35.689
# 3         0.001953   0.000         9.271       35.689
# 4         0.002441   0.001         9.271       35.689
# ...            ...     ...           ...          ...
# 655739  320.185547  38.032        12.397       36.508
# 655740  320.186035  38.040        12.397       36.508
# 655741  320.186523  38.048        12.397       36.508
# 655742  320.187012  38.056        12.397       36.508
# 655743  320.187500  38.064        12.397       36.508
#
# [655744 rows x 4 columns]

# %%
#GRAFICA DE PULSO
fig,D = plt.subplots(1,1,figsize=(15,5))
D.plot(df_datos2['B: BVP'])
D.set_ylabel('BVP',fontsize=20)
D.set_xlabel('time',fontsize=15)
D.set_xlim(50,680000)                               ## DATO TUNEADO
D.set_ylim(20,48)                                ## DATO TUNEADO
D.set_title('MD ambiguity',fontsize=20)

# GRAFO CONDUCTANCIA
fig,E = plt.subplots(1,1,figsize=(15,5))
E.plot(df_datos2['E: Skin Cond'])
E.set_ylabel('Skin Conductance',fontsize=20)
E.set_xlabel('time',fontsize=15)
E.set_title('MD ambiguity',fontsize=20)

#GRAFO RESPIRACION
fig,F = plt.subplots(1,1,figsize=(15,5))
F.plot(df_datos2['G: Abd Resp'])
F.set_ylabel('Breathing',fontsize=20)
F.set_xlabel('time',fontsize=15)
F.set_title('MD ambiguity',fontsize=20)
plt.show()

# %% [markdown]
# # Ambiguity    ft    Control

# %% [markdown]
# ###  B: BVP: ambiguity ft control

# %%
plt.figure(figsize=(15,5))
plt.xlim(500,650000)
plt.ylim(15,50)
plt.plot(df_datos1['B: BVP'],color = 'g', label='control')
plt.plot(df_datos2['B: BVP'],color = 'red', label='ambiguity ')
plt.ylabel('B: BVP',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('MD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# ### MD B: BVP: ambiguity ft control   RANDOM ZOOM

# %%
plt.figure(figsize=(15,5))
plt.xlim(90000,150000)
plt.ylim(30,45)
plt.plot(df_datos1['B: BVP'],color = 'g', label='control')
plt.plot(df_datos2['B: BVP'],color = 'red', label='ambiguity ')
plt.ylabel('B: BVP',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('MD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# ###  Skin Conductance: ambiguity ft control

# %%
plt.figure(figsize=(15,5))
plt.xlim(0,600000)  ## DATO TUNEADO
plt.ylim(3,11)
plt.plot(df_datos1['E: Skin Cond'],color = 'g', label='control')
plt.plot(df_datos2['E: Skin Cond'],color = 'red', label='ambiguity ')
plt.ylabel('Skin Conductance',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('MD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# ###  Abd Resp: ambiguity ft control

# %%
plt.figure(figsize=(15,5))
plt.xlim(0,550000)  ## DATO TUNEADO
#plt.ylim(3,11)
plt.plot(df_datos1['G: Abd Resp'],color = 'g', label='control')
plt.plot(df_datos2['G: Abd Resp'],color = 'red', label='ambiguity ')
plt.ylabel('G: Abd Resp',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('MD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# # Participante GD
#
# ## GD CONTROL

# %%
df_datos3 = pd.read_csv('GD_control.csv')
df_datos3
# Out:
#               Hora  B: BVP  E: Skin Cond  G: Abd Resp
# 0         0.000488   0.000        12.804       41.067
# 1         0.000977   0.000        12.804       41.067
# 2         0.001465   0.000        12.804       41.067
# 3         0.001953   0.000        12.804       41.067
# 4         0.002441   0.001        12.804       41.067
# ...            ...     ...           ...          ...
# 817659  399.248047  39.449        13.266       40.561
# 817660  399.248535  39.475        13.266       40.561
# 817661  399.249023  39.500        13.266       40.561
# 817662  399.249512  39.525        13.266       40.561
# 817663  399.250000  39.550        13.266       40.561
#
# [817664 rows x 4 columns]

# %%
#GRAFICA DE PULSO
fig,G = plt.subplots(1,1,figsize=(15,5))
G.plot(df_datos3['B: BVP'])
G.set_ylabel('BVP',fontsize=20)
G.set_xlabel('time',fontsize=15)
G.set_xlim(30,830000)                               ## DATO TUNEADO
G.set_ylim(30,50)                                ## DATO TUNEADO
G.set_title('GD control',fontsize=20)

# GRAFO CONDUCTANCIA
fig,H = plt.subplots(1,1,figsize=(15,5))
H.plot(df_datos3['E: Skin Cond'])
H.set_ylabel('Skin Conductance',fontsize=20)
H.set_xlabel('time',fontsize=15)
H.set_title('GD control',fontsize=20)

#GRAFO RESPIRACION
fig,I = plt.subplots(1,1,figsize=(15,5))
I.plot(df_datos3['G: Abd Resp'])
I.set_ylabel('Breathing',fontsize=20)
I.set_xlabel('time',fontsize=15)
I.set_title('GD control',fontsize=20)

plt.show()

# %% [markdown]
# ## GD AMBIGÜEDAD

# %%
df_datos4 = pd.read_csv('GD_ambiguedad.csv')
df_datos4
# Out:
#               Hora  B: BVP  E: Skin Cond  G: Abd Resp
# 0         0.000488   0.000        15.730        40.20
# 1         0.000977   0.000        15.730        40.20
# 2         0.001465   0.000        15.730        40.20
# 3         0.001953   0.000        15.730        40.20
# 4         0.002441   0.001        15.730        40.20
# ...            ...     ...           ...          ...
# 550139  268.623047  35.776        20.503        42.07
# 550140  268.623535  35.775        20.503        42.07
# 550141  268.624023  35.774        20.503        42.07
# 550142  268.624512  35.773        20.503        42.07
# 550143  268.625000  35.772        20.503        42.07
#
# [550144 rows x 4 columns]

# %%
#GRAFICA DE PULSO
fig,J = plt.subplots(1,1,figsize=(15,5))
J.plot(df_datos4['B: BVP'])
J.set_ylabel('BVP',fontsize=20)
J.set_xlabel('time',fontsize=15)
J.set_xlim(50,500000)                           ## DATO TUNEADO
J.set_ylim(30,45)                           ## DATO TUNEADO
J.set_title('GD ambigüedad',fontsize=20)

# GRAFO CONDUCTANCIA
fig,K = plt.subplots(1,1,figsize=(15,5))
K.plot(df_datos4['E: Skin Cond'])
K.set_ylabel('Skin Conductance',fontsize=20)
K.set_xlabel('time',fontsize=15)
K.set_title('GD ambigüedad',fontsize=20)

#GRAFO RESPIRACION
fig,L = plt.subplots(1,1,figsize=(15,5))
L.plot(df_datos4['G: Abd Resp'])
L.set_ylabel('Breathing',fontsize=20)
L.set_xlabel('time',fontsize=15)
L.set_title('GD ambigüedad',fontsize=20)

plt.show()

# %% [markdown]
# # Ambiguity    ft    Control

# %% [markdown]
# ###  B: BVP: ambiguity ft control

# %%
plt.figure(figsize=(15,5))
plt.xlim(500,700000)  ## DATO TUNEADO
plt.ylim(30,50)
plt.plot(df_datos3['B: BVP'],color = 'g', label='control')
plt.plot(df_datos4['B: BVP'],color = 'red', label='ambiguity ')
plt.ylabel('B: BVP',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('GD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# ### MD B: BVP: ambiguity ft control   RANDOM ZOOM

# %%
plt.figure(figsize=(15,5))
plt.xlim(330000,500000)
plt.ylim(30,45)
plt.plot(df_datos3['B: BVP'],color = 'g', label='control')
plt.plot(df_datos4['B: BVP'],color = 'red', label='ambiguity ')
plt.ylabel('B: BVP',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('GD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# ###  Skin Conductance: ambiguity ft control

# %%
plt.figure(figsize=(15,5))
plt.xlim(0,550000)  ## DATO TUNEADO
#plt.ylim(3,11)
plt.plot(df_datos3['E: Skin Cond'],color = 'g', label='control')
plt.plot(df_datos4['E: Skin Cond'],color = 'red', label='ambiguity ')
plt.ylabel('Skin Conductance',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('GD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# ###  Abd Resp: ambiguity ft control

# %%
plt.figure(figsize=(15,5))
plt.xlim(0,550000)  ## DATO TUNEADO
#plt.ylim(3,11)
plt.plot(df_datos3['G: Abd Resp'],color = 'g', label='control')
plt.plot(df_datos4['G: Abd Resp'],color = 'red', label='ambiguity ')
plt.ylabel('G: Abd Resp',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('GD ambiguity ft control',fontsize=20)
plt.show()

# %% [markdown]
# # Participante PL
#
# ## PL CONTROL

# %%
df_datos5 = pd.read_csv('PL_control.csv')
df_datos5
# Out:
#              'Hora'  'B:BVP'  'E:Skin Cond'  'G:Abd Resp'
# 0          0.000488    0.000         11.467        34.556
# 1          0.000977    0.000         11.467        34.556
# 2          0.001465    0.000         11.467        34.556
# 3          0.001953    0.000         11.467        34.556
# 4          0.002441    0.001         11.467        34.556
# ...             ...      ...            ...           ...
# 1011707  493.998047   26.639          7.357        37.069
# 1011708  493.998535   26.645          7.357        37.069
# 1011709  493.999023   26.650          7.357        37.069
# 1011710  493.999512   26.656          7.357        37.069
# 1011711  494.000000   26.662          7.357        37.069
#
# [1011712 rows x 4 columns]

# %%
df_datos5.loc[3]
# Out:
# 'Hora'            0.001953
# 'B:BVP'           0.000000
# 'E:Skin Cond'    11.467000
# 'G:Abd Resp'     34.556000
# Name: 3, dtype: float64

# %%
#GRAFICA DE PULSO
fig,M = plt.subplots(1,1,figsize=(15,5))
M.plot(df_datos5["'B:BVP'"])
M.set_ylabel('BVP',fontsize=20)
M.set_xlabel('time',fontsize=15)
M.set_title('PL control',fontsize=20)

# GRAFO CONDUCTANCIA
fig,N = plt.subplots(1,1,figsize=(15,5))
N.plot(df_datos5["'E:Skin Cond'"])
N.set_ylabel('Skin Conductance',fontsize=20)
N.set_xlabel('time',fontsize=15)
N.set_title('PL control',fontsize=20)

#GRAFO RESPIRACION
fig,L = plt.subplots(1,1,figsize=(15,5))
L.plot(df_datos5["'G:Abd Resp'"])
L.set_ylabel('Breathing',fontsize=20)
L.set_xlabel('time',fontsize=15)
L.set_title('PL control',fontsize=20)

plt.show()

# %% [markdown]
# ## PL AMBIGÜEDAD

# %%
df_datos6 = pd.read_csv('PL_ambiguedad.csv')
df_datos6
# Out:
#        Hora,B: BVP,E: Skin Cond,G: Abd Resp
# 0              0.00048828125,0,9.445,34.356
# 1              0.00097656250,0,9.445,34.356
# 2              0.00146484375,0,9.445,34.356
# 3              0.00195312500,0,9.445,34.356
# 4          0.00244140625,0.001,9.445,34.356
# ...                                     ...
# 674171   329.18554687500,32.414,7.67,36.146
# 674172   329.18603515625,32.413,7.67,36.146
# 674173   329.18652343750,32.412,7.67,36.146
# 674174   329.18701171875,32.411,7.67,36.146
# 674175    329.18750000000,32.41,7.67,36.146
#
# [674176 rows x 1 columns]

# %% [markdown]
# # BORRADOR

# %%
#GRAFICA DE PULSO
plt.plot(df_datos5["'B:BVP'"])
plt.show()

# %%
#PARA QUITAR LA FILA CERO DE LOS DATOS

without_Row = df_datos.drop(df_datos.index[[0,1]])
without_Row
#df_datos(df_datos['B:BVP'] > 30)
# Out:
#              'Hora'  'B: BVP'  'E: Skin Cond'  'G: Abd Resp' 'Evento'
# 2          0.001465     0.000          11.467         34.556      ' '
# 3          0.001953     0.000          11.467         34.556      ' '
# 4          0.002441     0.001          11.467         34.556      ' '
# 5          0.002930     0.001          11.467         34.556      ' '
# 6          0.003418     0.002          11.467         34.556      ' '
# ...             ...       ...             ...            ...      ...
# 1011707  493.998047    26.639           7.357         37.069      ' '
# 1011708  493.998535    26.645           7.357         37.069      ' '
# 1011709  493.999023    26.650           7.357         37.069      ' '
# 1011710  493.999512    26.656           7.357         37.069      ' '
# 1011711  494.000000    26.662           7.357         37.069      ' '
#
# [1011710 rows x 5 columns]

# %%
plt.plot(without_Row['B: BVP'])
plt.ylabel('BVP',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('PL control',fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B: BVP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-a254aa855457> in <module>
# ...

# %% [markdown]
# ## Ploteo de rangos específicos (extracción  de información al azar)

# %%
plt.plot(without_Row['B: BVP'])
plt.ylabel('BVP',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('PL control',fontsize=20)
plt.xlim(180000,150000)
plt.ylim(25,45)
plt.show()

# %%
plt.plot(without_Row['E: Skin Cond'])
plt.ylabel('Skin Conductance',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('PL control',fontsize=20)
plt.show()

# %%
plt.plot(without_Row['G: Abd Resp'])
plt.ylabel('Breathing',fontsize=20)
plt.xlabel('time',fontsize=15)
plt.title('PL control',fontsize=20)
plt.show()

# %% [markdown]
# ## PL AMBIGÜEDAD

# %%
# read csv
df_datos = pd.read_csv('prueba.csv')
df_datos
# Out:
#                                       Hora  B: BVP  E: Skin Cond  G: Abd Resp
# 0             0.00048828125,0,9.445,34.356     NaN           NaN          NaN
# 1             0.00097656250,0,9.445,34.356     NaN           NaN          NaN
# 2             0.00146484375,0,9.445,34.356     NaN           NaN          NaN
# 3             0.00195312500,0,9.445,34.356     NaN           NaN          NaN
# 4         0.00244140625,0.001,9.445,34.356     NaN           NaN          NaN
# ...                                    ...     ...           ...          ...
# 674171  329.18554687500,32.414,7.67,36.146     NaN           NaN          NaN
# 674172  329.18603515625,32.413,7.67,36.146     NaN           NaN          NaN
# 674173  329.18652343750,32.412,7.67,36.146     NaN           NaN          NaN
# 674174  329.18701171875,32.411,7.67,36.146     NaN           NaN          NaN
# 674175   329.18750000000,32.41,7.67,36.146     NaN           NaN          NaN
#
# [674176 rows x 4 columns]

# %%
# read csv
df_datos = pd.read_csv('PL_ambiguedad.csv')
df_datos
# Out:
#        Hora,B: BVP,E: Skin Cond,G: Abd Resp
# 0              0.00048828125,0,9.445,34.356
# 1              0.00097656250,0,9.445,34.356
# 2              0.00146484375,0,9.445,34.356
# 3              0.00195312500,0,9.445,34.356
# 4          0.00244140625,0.001,9.445,34.356
# ...                                     ...
# 674171   329.18554687500,32.414,7.67,36.146
# 674172   329.18603515625,32.413,7.67,36.146
# 674173   329.18652343750,32.412,7.67,36.146
# 674174   329.18701171875,32.411,7.67,36.146
# 674175    329.18750000000,32.41,7.67,36.146
#
# [674176 rows x 1 columns]

# %%
df_datos.loc[[3]]
# Out:
#   Hora,B: BVP,E: Skin Cond,G: Abd Resp
# 3         0.00195312500,0,9.445,34.356

# %%
df_datos.loc[3]
# Out:
# Hora,B: BVP,E: Skin Cond,G: Abd Resp    0.00195312500,0,9.445,34.356
# Name: 3, dtype: object

# %%
# split column and add new columns to df
df_datos[['Hora','B: BVP','E: Skin Cond','G: Abd Resp']] = df['Hora,B: BVP,E: Skin Cond,G: Abd Resp'].str.split(',', expand=True)
# display the dataframe
df_datos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b002f3d97102> in <module>
#       1 # split column and add new columns to df
# ----> 2 df_datos[['Hora','B: BVP','E: Skin Cond','G: Abd Resp']] = df['Hora,B: BVP,E: Skin Cond,G: Abd Resp'].str.split(',', expand=True)
#       3 # display the dataframe
#       4 df_datos
#
# NameError: name 'df' is not defined
